# %% [markdown]
# # Translations for Dataset Categories
#
# ### Κατηγορία: ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ (Category: ACCIDENT NATURE)
# ## Υποκατηγορίες (Subcategories):
# Θανατηφόρο (Fatal)
# Προκάλεσε Τραυματισμούς (Caused Injuries)
#
# ### Κατηγορία: ΠΕΡΙΟΧΗ ΑΤΥΧΗΜΑΤΟΣ (Category: ACCIDENT AREA)
# ## Υποκατηγορίες (Subcategories):
# Αττική (Attica)
# Λοιπή Χώρα (Rest of the Country)
#
# ### Κατηγορία: ΠΕΡΙΦΕΡΕΙΕΣ (Category: REGIONS)
# ## Υποκατηγορίες (Subcategories):
# Ανατολική Μακεδονία & Θράκη (Eastern Macedonia & Thrace)
# Κεντρική Μακεδονία (Central Macedonia)
# Δυτική Μακεδονία (Western Macedonia)
# Ήπειρος (Epirus)
# Θεσσαλία (Thessaly)
# Ιόνιοι Νήσοι (Ionian Islands)
# Δυτική Ελλάδα (Western Greece)
# Στερεά Ελλάδα (Central Greece)
# Αττική (Attica)
# Πελοπόννησος (Peloponnese)
# Βόρειο Αιγαίο (Northern Aegean)
# Νότιο Αιγαίο (Southern Aegean)
# Κρήτη (Crete)
#
# ## Κατηγορία: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ (Category: AREA TYPE)
# ### Υποκατηγορίες (Subcategories):Κατοικημένη (Inhabited)
# Μη κατοικημένη (Uninhabited)
#
# ### Κατηγορία: ΕΙΔΟΣ ΟΔΟΥ (Category: ROAD TYPE)
# ## Υποκατηγορίες (Subcategories):
# Αυτοκινητόδρομος (Highway)
# Εθνική οδός (National road)
# Επαρχιακή οδός (Provincial road)
# Δημοτική οδός (Municipal road)
# Άλλο (Other)
#
#
# ### Κατηγορία: ΜΗΝΑΣ (Category: MONTH)
# ## Υποκατηγορίες (Subcategories):
# Ιανουάριος (January)
# Φεβρουάριος (February)
# Μάρτιος (March)
# Απρίλιος (April)
# Μάιος (May)
# Ιούνιος (June)
# Ιούλιος (July)
# Αύγουστος (August)
# Σεπτέμβριος (September)
# Οκτώβριος (October)
# Νοέμβριος (November)
# Δεκέμβριος (December)
#
#
# ### Κατηγορία: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ (Category: DAY OF WEEK)
# ## Υποκατηγορίες (Subcategories):
# Κυριακή (Sunday)
# Δευτέρα (Monday)
# Τρίτη (Tuesday)
# Τετάρτη (Wednesday)
# Πέμπτη (Thursday)
# Παρασκευή (Friday)
# Σάββατο (Saturday)
#
# ## Κατηγορία: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ (Category: ACCIDENT TIME)
# ### Υποκατηγορίες (Subcategories):
# 0-4
# 5-8
# 9-12
# 13-16
# 17-20
# 21-23
#
# ## Κατηγορία: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ (Category: TRANSPORTATION MEANS)
# ### Υποκατηγορίες (Subcategories):
# Σύνολο οχημάτων (Total vehicles)
# Επιβατικά (Passenger cars)
# Μοτοσυκλέτες (Motorcycles)
# Μοτοποδήλατα (Mopeds)
# Ποδήλατα (Bicycles)
# Φορτηγά μέχρι 3.5 τόνους (Trucks up to 3.5 tons)
# Φορτηγά άνω των 3.5 τόνων (Trucks over 3.5 tons)
# Λεωφορεία (Buses)
# Άλλο είδος οχήματος (Other vehicle types)

# %%
import pandas as pd
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import interact
import dash
from plotly.subplots import make_subplots
from dash import dcc, html, callback
from dash.dependencies import Input, Output, State
import plotly.express as px
import plotly.graph_objects as go

# %%
# Assuming your DataFrame is named df
df = pd.read_csv('C:/Users/EFKA-PC/Desktop/github1/odika/data.csv')

# %%
import pandas as pd

# Specify the path to your CSV file
#csv_file_path = 'C:/Users/Dimitris/Desktop/project spotify/odika/data.csv'


csv_file_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
# Load the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame
df
# Out:
#               Category                  Subcategory   2007   2008   2009  \
# 0    Σύνολο ατυχημάτων                          NaN  15499  15083  14789
# 1      ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ                   Θανατηφόρο   1442   1411   1296
# 2      ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ      Προκάλεσε Τραυματισμούς  14057  13672  13493
# 3   ΠΕΡΙΟΧΗ ΑΤΥΧΗΜΑΤΟΣ                       Αττική   7918   7562   7826
# 4   ΠΕΡΙΟΧΗ ΑΤΥΧΗΜΑΤΟΣ                   Λοιπή Χώρα   7581   7521   6963
# 5          ΠΕΡΙΦΕΡΕΙΕΣ  Ανατολική Μακεδονία & Θράκη    608    670    633
# 6          ΠΕΡΙΦΕΡΕΙΕΣ           Κεντρική Μακεδονία   2537   2445   2137
# 7          ΠΕΡΙΦΕΡΕΙΕΣ             Δυτική Μακεδονία    104    113    127
# 8          ΠΕΡΙΦΕΡΕΙΕΣ                      Ήπειρος    184    178    148
# 9          ΠΕΡΙΦΕΡΕΙΕΣ                     Θεσσαλία    431    416    415
# 10         ΠΕΡΙΦΕΡΕΙΕΣ                 Ιόνιοι Νήσοι    251    247    233
# 11         ΠΕΡΙΦΕΡΕΙΕΣ                Δυτική Ελλάδα    802    783    660
# 12         ΠΕΡΙΦΕΡΕΙΕΣ                Στερεά Ελλάδα    855    884    966
# 13         ΠΕΡΙΦΕΡΕΙΕΣ                       Αττική   7918   7562   7826
# 14         ΠΕΡΙΦΕΡΕΙΕΣ                 Πελοπόννησος    881    942    871
# 15         ΠΕΡΙΦΕΡΕΙΕΣ                Βόρειο Αιγαίο    175    168    117
# 16         ΠΕΡΙΦΕΡΕΙΕΣ                 Νότιο Αιγαίο    287    313    266
# 17         ΠΕΡΙΦΕΡΕΙΕΣ                        Κρήτη    466    362    390
# 18      ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ                  Κατοικημένη  12011  11623  11476
# 19      ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ               Μη κατοικημένη   3488   3460   3313
# 20          ΕΙΔΟΣ ΟΔΟΥ             Αυτοκινητόδρομος    611    630    680
# 21          ΕΙΔΟΣ ΟΔΟΥ                  Εθνική οδός   2046   2055   1964
# 22          ΕΙΔΟΣ ΟΔΟΥ               Επαρχιακή οδός   1738   1700   1604
# 23          ΕΙΔΟΣ ΟΔΟΥ                Δημοτική οδός  10954  10579  10429
# 24          ΕΙΔΟΣ ΟΔΟΥ                         Άλλο    150    119    112
# 25               ΜΗΝΑΣ                   Ιανουάριος   1234    965   1037
# 26               ΜΗΝΑΣ                  Φεβρουάριος   1042    958   1068
# 27               ΜΗΝΑΣ                      Μάρτιος   1311   1088   1206
# 28               ΜΗΝΑΣ                     Απρίλιος   1291   1203   1216
# 29               ΜΗΝΑΣ                        Μάιος   1378   1365   1381
# 30               ΜΗΝΑΣ                      Ιούνιος   1351   1511   1407
# 31               ΜΗΝΑΣ                      Ιούλιος   1561   1504   1510
# 32               ΜΗΝΑΣ                    Αύγουστος   1267   1328   1256
# 33               ΜΗΝΑΣ                  Σεπτέμβριος   1346   1329   1202
# 34               ΜΗΝΑΣ                    Οκτώβριος   1348   1452   1240
# 35               ΜΗΝΑΣ                    Νοέμβριος   1208   1263   1161
# 36               ΜΗΝΑΣ                   Δεκέμβριος   1162   1117   1105
# 37     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                      Κυριακή   2108   2116   2061
# 38     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                      Δευτέρα   2158   2158   2103
# 39     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                        Τρίτη   2150   2111   2117
# 40     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                      Τετάρτη   2114   2143   2072
# 41     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                       Πέμπτη   2271   2134   2223
# 42     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                    Παρασκευή   2439   2219   2261
# 43     ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ                      Σάββατο   2259   2202   1952
# 44      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                          0-4   1770   1666   1582
# 45      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                          5-8   1761   1674   1636
# 46      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                         9-12   3019   2922   2977
# 47      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                        13-16   3770   3589   3522
# 48      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                        17-20   3270   3299   3245
# 49      ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ                        21-23   1909   1933   1827
# 50      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ              Σύνολο οχημάτων  26890  26002  25645
# 51      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ                    Επιβατικά  15458  14668  14858
# 52      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ                 Μοτοσυκλέτες   7585   7657   7330
# 53      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ                 Μοτοποδήλατα    663    537    538
# 54      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ                     Ποδήλατα    227    224    218
# 55      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ     Φορτηγά μέχρι 3.5 τόνους   1580   1482   1440
# 56      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ    Φορτηγά άνω των 3.5 τόνων    567    606    482
# 57      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ                    Λεωφορεία    349    365    321
# 58      ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ          Άλλο είδος οχήματος    461    463    458
#
#      2010   2011   2012   2013   2014   2015   2016   2017   2018   2019  \
# 0   15032  13849  12398  12109  11690  11440  11318  10848  10737  10712
# 1    1142   1051    908    814    739    741    772    679    645    656
# 2   13890  12798  11490  11295  10951  10699  10546  10169  10092  10056
# 3    7424   6815   6490   6236   6197   5706   5634   5545   5519   5682
# 4    7608   7034   5908   5873   5493   5734   5684   5303   5218   5030
# 5     633    605    531    465    456    484    445    366    404    376
# 6    2572   2555   2183   2379   2204   2299   2450   2070   1844   1854
# 7     199    236    142    131     76    100     89     75     61     62
# 8     162    166    147    148    157    136    140    119    146    103
# 9     488    456    375    318    275    235    224    221    200    229
# 10    305    237    190    198    168    184    187    174    146    196
# 11    694    573    473    518    486    574    492    508    545    457
# 12    704    626    489    478    408    432    431    502    471    456
# 13   7424   6815   6490   6236   6197   5706   5634   5545   5519   5682
# 14    777    660    605    577    633    635    564    528    543    476
# 15    186    154    110     94    108    105    138    177    226    222
# 16    478    402    361    278    317    341    320    393    464    433
# 17    410    364    302    289    205    209    204    170    168    166
# 18  11887  11014  10011   9951   9786   9293   9271   8870   8794   8941
# 19   3145   2835   2387   2158   1904   2147   2047   1978   1943   1771
# 20    548    564    439    466    282    303    284    313    354    279
# 21   1817   1569   1264   1077   1229   1198   1173    994    942    800
# 22   1665   1583   1382   1272   1131   1216   1183   1092   1138   1072
# 23  10900   9975   9147   9147   8929   8631   8632   8404   8252   8496
# 24    102    158    166    147    119     92     46     45     51     65
# 25   1082    964    879    861    860    762    810    645    778    676
# 26   1130    943    705    800    859    700    769    757    684    693
# 27   1299    965    983    948    893    770    864    758    890    839
# 28   1279   1152   1036   1031    881    942   1043    886    869    856
# 29   1424   1184   1048   1058   1105   1065    997    969    866    978
# 30   1380   1363   1203   1077   1119   1006   1022    998    939   1024
# 31   1384   1382   1250   1147   1159   1171   1094   1050   1016   1073
# 32   1315   1235   1054   1052   1049   1030    923    923    931    969
# 33   1244   1216   1105   1091    999    970    947   1034    934    917
# 34   1174   1166   1162   1139    992    921    989   1056   1010   1020
# 35   1137   1124   1006    938    877   1002    978    857    955    838
# 36   1184   1155    967    967    897   1101    882    915    865    829
# 37   2040   1848   1644   1485   1492   1452   1446   1395   1372   1296
# 38   2116   2018   1867   1763   1629   1631   1597   1561   1530   1524
# 39   2108   1928   1686   1806   1759   1636   1628   1542   1541   1553
# 40   2147   1958   1720   1739   1612   1649   1604   1573   1529   1535
# 41   2136   2030   1798   1773   1723   1784   1650   1626   1577   1626
# 42   2376   2133   1931   1903   1862   1748   1841   1616   1672   1696
# 43   2109   1934   1752   1640   1613   1540   1552   1535   1516   1482
# 44   1537   1395   1197   1017   1012    944    925    872    839    844
# 45   1594   1574   1364   1320   1245   1222   1187   1159   1090   1095
# 46   3085   2962   2705   2712   2562   2434   2433   2355   2450   2359
# 47   3677   3355   3012   2985   2852   2996   2917   2803   2763   2761
# 48   3303   2914   2652   2568   2656   2393   2489   2404   2316   2311
# 49   1836   1649   1468   1507   1363   1451   1367   1255   1279   1342
# 50  26109  23794  21120  20660  19895  19246  19122  18131  17985  18153
# 51  14642  13139  11728  11385  10958  10483  10371   9767   9600   9727
# 52   7762   7328   6625   6656   6472   6208   6263   6039   6038   6094
# 53    683    580    465    441    411    496    437    395    418    394
# 54    251    304    279    297    261    275    251    240    222    257
# 55   1447   1162   1049   1015    976    945    942    889    919    901
# 56    526    436    379    336    341    321    333    309    309    283
# 57    325    311    274    275    261    281    251    251    238    227
# 58    473    534    321    255    215    237    274    241    241    270
#
#      2020   2021
# 0    9083  10454
# 1     552    584
# 2    8531   9870
# 3    4965   5760
# 4    4118   4694
# 5     297    295
# 6    1564   1919
# 7      47     51
# 8     108    106
# 9     210    238
# 10    117    172
# 11    440    405
# 12    413    482
# 13   4965   5760
# 14    333    322
# 15    127    150
# 16    325    408
# 17    137    146
# 18   7807   8755
# 19   1276   1699
# 20    210    281
# 21    581    723
# 22    709   1043
# 23   7512   8344
# 24     71     63
# 25    797    578
# 26    853    527
# 27    518    627
# 28    312    740
# 29    738    974
# 30    898    984
# 31    982   1204
# 32    878   1019
# 33    995   1049
# 34    912   1047
# 35    651    898
# 36    549    807
# 37   1014   1260
# 38   1359   1467
# 39   1353   1540
# 40   1321   1549
# 41   1359   1572
# 42   1444   1669
# 43   1233   1397
# 44    667    854
# 45    797    939
# 46   2124   2266
# 47   2351   2740
# 48   2002   2386
# 49   1142   1269
# 50  15383  17914
# 51   7999   9297
# 52   5460   6494
# 53    306    343
# 54    250    289
# 55    799    886
# 56    179    169
# 57    143    202
# 58    247    234

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load the dataset
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Select the relevant columns for the spider chart
selected_columns = ['Category', 'Subcategory', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']
df_spider = df[selected_columns]

# Function to plot spider chart
def plot_spider_chart(row, ax):
    categories = df_spider.columns[2:]  # Exclude 'Category' and 'Subcategory' from categories
    values = row[selected_columns[2:]].values

    num_vars = len(categories)
    angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
    angles += angles[:1]

    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    ax.set_rlabel_position(0)
    ax.set_yticklabels([])
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Repeat the first value to close the circle
    values = list(values) + [values[0]]
    angles += [angles[0]]  # Add an extra angle to match the length

    ax.plot(angles, values, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color='skyblue', alpha=0.4)

# Create subplots for each row in the dataset
fig, axes = plt.subplots(nrows=len(df), ncols=1, subplot_kw=dict(projection='polar'), figsize=(10, 5 * len(df)))

# Plot spider charts
for i, ax in enumerate(axes):
    plot_spider_chart(df_spider.iloc[i], ax)

# Add numerical values to the plot
for i, ax in enumerate(axes):
    categories = df_spider.columns[2:]
    values = df_spider.iloc[i][selected_columns[2:]].values
    for j, (angle, value) in enumerate(zip(angles, values)):
        ax.text(angle, ax.get_rmax() + 1, f"{categories[j]}: {value}", ha='center', va='center')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 41
#      39 # Plot spider charts
#      40 for i, ax in enumerate(axes):
# ---> 41     plot_spider_chart(df_spider.iloc[i], ax)
#      43 # Add numerical values to the plot
#      44 for i, ax in enumerate(axes):
#
# Cell In[48], line 33, in plot_spider_chart(row, ax)
#      30 values = list(values) + [values[0]]
#      31 angles += [angles[0]]  # Add an extra angle to match the length
# ---> 33 ax.plot(angles, values, linewidth=2, linestyle='solid')
#      34 ax.fill(angles, values, color='skyblue', alpha=0.4)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (17,) and (16,)

# %%
# Assuming your DataFrame is named 'df'
categories = df['Category'].unique()

# Iterate through each category and print its corresponding subcategories
for category in categories:
    subcategories = df[df['Category'] == category]['Subcategory'].unique()
    
    print(f"\nCategory: {category}")
    print("Subcategories:")
    
    for subcategory in subcategories:
        print(subcategory)
# Out:
# Category: Σύνολο ατυχημάτων
# Subcategories:
# nan
#
# Category: ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ
# Subcategories:
# Θανατηφόρο
# Προκάλεσε Τραυματισμούς
#
# Category: ΠΕΡΙΟΧΗ ΑΤΥΧΗΜΑΤΟΣ
# Subcategories:
# Αττική
# Λοιπή Χώρα
#
# Category: ΠΕΡΙΦΕΡΕΙΕΣ
# Subcategories:
# Ανατολική Μακεδονία & Θράκη
# Κεντρική Μακεδονία
# Δυτική Μακεδονία
# Ήπειρος
# Θεσσαλία
# Ιόνιοι Νήσοι
# Δυτική Ελλάδα
# Στερεά Ελλάδα
# Αττική
# Πελοπόννησος
# Βόρειο Αιγαίο
# Νότιο Αιγαίο
# Κρήτη
#
# Category: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ
# Subcategories:
# Κατοικημένη
# Μη κατοικημένη
#
# Category: ΕΙΔΟΣ ΟΔΟΥ
# Subcategories:
# Αυτοκινητόδρομος
# Εθνική οδός
# Επαρχιακή οδός
# Δημοτική οδός
# Άλλο
#
# Category: ΜΗΝΑΣ
# Subcategories:
# Ιανουάριος
# Φεβρουάριος
# Μάρτιος
# Απρίλιος
# Μάιος
# Ιούνιος
# Ιούλιος
# Αύγουστος
# Σεπτέμβριος
# Οκτώβριος
# Νοέμβριος
# Δεκέμβριος
#
# Category: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ
# Subcategories:
# Κυριακή
# Δευτέρα
# Τρίτη
# Τετάρτη
# Πέμπτη
# Παρασκευή
# Σάββατο
#
# Category: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ
# Subcategories:
# 0-4
# 5-8
# 9-12
# 13-16
# 17-20
# 21-23
#
# Category: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ
# Subcategories:
# Σύνολο οχημάτων
# Επιβατικά
# Μοτοσυκλέτες
# Μοτοποδήλατα
# Ποδήλατα
# Φορτηγά μέχρι 3.5 τόνους
# Φορτηγά άνω των 3.5 τόνων
# Λεωφορεία
# Άλλο είδος οχήματος

# %%
import matplotlib.pyplot as plt

# Sample data
safest_conditions = {
    'Month': 'February',
    'Day': 'Sunday',
    'Time Period': '00:00 - 04:00',
    'Area Type': 'Uninhabited',
    'Region': 'Western Macedonia',
    'Road Type': 'National Highway',
    'Vehicle Type': 'Trucks > 3.5 tons'
}

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart
bars = ax.bar(safest_conditions.keys(), [1] * len(safest_conditions), color='green')

# Highlighting the safest conditions in red
for i, bar in enumerate(bars):
    if safest_conditions[list(safest_conditions.keys())[i]] == 'February':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == 'Sunday':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == '00:00 - 04:00':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == 'Uninhabited':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == 'Western Macedonia':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == 'National Highway':
        bar.set_color('red')
    elif safest_conditions[list(safest_conditions.keys())[i]] == 'Trucks > 3.5 tons':
        bar.set_color('red')

# Adding labels and title
ax.set_ylabel('Safest Conditions')
ax.set_title('Safest Conditions for Driving')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
safest_conditions = {
    'Month': 'February',
    'Day': 'Sunday',
    'Time Period': '00:00 - 04:00',
    'Area Type': 'Uninhabited',
    'Region': 'Western Macedonia',
    'Road Type': 'National Highway',
    'Vehicle Type': 'Trucks > 3.5 tons'
}

# Assign weights for each condition based on safety
weights = {
    'Month': 0.2,
    'Day': 0.1,
    'Time Period': 0.3,
    'Area Type': 0.4,
    'Region': 0.5,
    'Road Type': 0.4,
    'Vehicle Type': 0.5
}

# Calculate total safety score
total_score = sum(weights[condition] for condition in safest_conditions)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart with weighted values
bars = ax.bar(safest_conditions.keys(), [weights[condition] for condition in safest_conditions], color='green')

# Highlighting the conditions in proportion to their safety contribution
for bar in bars:
    bar.set_color('lightgreen')

# Adding labels and title
ax.set_ylabel('Safety Contribution')
ax.set_title('Safety Contribution of Driving Conditions')

# Show the total safety score
ax.text(0.5, 1.05, f'Total Safety Score: {total_score:.2f}', transform=ax.transAxes, ha='center', va='center', fontsize=12)

# Adding labels to the bars
for bar, condition in zip(bars, safest_conditions.values()):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02, condition, ha='center', va='bottom')

# Show the plot
plt.show()

# %%
df.columns
# Out:
# Index(['Category', 'Subcategory', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'Κατηγορία': 'ΜΗΝΑΣ',
    'Υποκατηγορία': 'Φεβρουάριος',
    'Κατηγορία: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ': 'Κυριακή',
    'Κατηγορία: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ': '00:00 - 04:00',
    'Κατηγορία: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ': 'Μη κατοικημένη',
    'Κατηγορία: ΠΕΡΙΦΕΡΕΙΕΣ': 'Δυτική Μακεδονία',
    'Κατηγορία: ΕΙΔΟΣ ΟΔΟΥ': 'Εθνική οδός',
    'Κατηγορία: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ': 'Φορτηγά άνω των 3.5 τόνων'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    condition_values = df[df['Category'] == condition]['Subcategory'].unique()
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].shape[0]
    weights[condition] = total_weight / df.shape[0]

# Calculate total safety score
total_score = sum(weights[condition] for condition in safest_conditions)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart with weighted values
bars = ax.bar(safest_conditions.keys(), [weights[condition] for condition in safest_conditions], color='green')

# Highlighting the conditions in proportion to their safety contribution
for bar in bars:
    bar.set_color('lightgreen')

# Adding labels and title
ax.set_ylabel('Safety Contribution')
ax.set_title('Safety Contribution of Driving Conditions')

# Show the total safety score
ax.text(0.5, 1.05, f'Total Safety Score: {total_score:.2f}', transform=ax.transAxes, ha='center', va='center', fontsize=12)

# Adding labels to the bars
for bar, condition in zip(bars, safest_conditions.values()):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.02, condition, ha='center', va='bottom')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'Κατηγορία': 'ΜΗΝΑΣ',
    'Υποκατηγορία': 'Φεβρουάριος',
    'Κατηγορία: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ': 'Κυριακή',
    'Κατηγορία: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ': '00:00 - 04:00',
    'Κατηγορία: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ': 'Μη κατοικημένη',
    'Κατηγορία: ΠΕΡΙΦΕΡΕΙΕΣ': 'Δυτική Μακεδονία',
    'Κατηγορία: ΕΙΔΟΣ ΟΔΟΥ': 'Εθνική οδός',
    'Κατηγορία: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ': 'Φορτηγά άνω των 3.5 τόνων'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    condition_values = df[df['Category'] == condition]['Subcategory'].unique()
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].shape[0]
    weights[condition] = total_weight / df.shape[0]

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'MONTH': 'February',
    'DAY_OF_WEEK': 'Sunday',
    'ACCIDENT_TIME': '00:00 - 04:00',
    'AREA_TYPE': 'Uninhabited',
    'REGIONS': 'Western Macedonia',
    'ROAD_TYPE': 'National Highway',
    'TRANSPORTATION_MEANS': 'Trucks over 3.5 tons'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].iloc[:, 2:].sum().sum()
    weights[condition] = total_weight / df.iloc[:, 2:].sum().sum()

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Add numerical data labels
for angle, label, value in zip(angles, labels, values):
    ax.text(angle, value, f'{value:.2%}', ha='center', va='center')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'ΜΗΝΑΣ': 'Φεβρουάριος',
    'Κατηγορία: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ': 'Κυριακή',
    'Κατηγορία: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ': '00:00 - 04:00',
    'Κατηγορία: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ': 'Μη κατοικημένη',
    'Κατηγορία: ΠΕΡΙΦΕΡΕΙΕΣ': 'Δυτική Μακεδονία',
    'Κατηγορία: ΕΙΔΟΣ ΟΔΟΥ': 'Εθνική οδός',
    'Κατηγορία: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ': 'Φορτηγά άνω των 3.5 τόνων'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    condition_values = df[df['Category'] == condition]['Subcategory'].unique()
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].shape[0]
    weights[condition] = total_weight / df.shape[0]

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'ΜΗΝΑΣ': 'Φεβρουάριος',
    'Κατηγορία: ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ': 'Κυριακή',
    'Κατηγορία: ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ': '00:00 - 04:00',
    'Κατηγορία: ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ': 'Μη κατοικημένη',
    'Κατηγορία: ΠΕΡΙΦΕΡΕΙΕΣ': 'Δυτική Μακεδονία',
    'Κατηγορία: ΕΙΔΟΣ ΟΔΟΥ': 'Εθνική οδός',
    'Κατηγορία: ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ': 'Φορτηγά άνω των 3.5 τόνων'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].iloc[:, 2:].sum().sum()
    weights[condition] = total_weight / df.iloc[:, 2:].sum().sum()

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'MONTH': 'February',
    'DAY_OF_WEEK': 'Sunday',
    'ACCIDENT_TIME': '00:00 - 04:00',
    'AREA_TYPE': 'Uninhabited',
    'REGIONS': 'Western Macedonia',
    'ROAD_TYPE': 'National Highway',
    'TRANSPORTATION_MEANS': 'Trucks over 3.5 tons'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].iloc[:, 2:].sum().sum()
    weights[condition] = total_weight / df.iloc[:, 2:].sum().sum()

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load data from the CSV file
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Sample data
safest_conditions = {
    'MONTH': 'February',
    'DAY_OF_WEEK': 'Sunday',
    'ACCIDENT_TIME': '00:00 - 04:00',
    'AREA_TYPE': 'Uninhabited',
    'REGIONS': 'Western Macedonia',
    'ROAD_TYPE': 'National Highway',
    'TRANSPORTATION_MEANS': 'Trucks over 3.5 tons'
}

# Calculate weights based on the data
weights = {}
for condition, value in safest_conditions.items():
    total_weight = df[(df['Category'] == condition) & (df['Subcategory'] == value)].iloc[:, 2:].sum().sum()
    total_weight_all = df.iloc[:, 2:].sum().sum()
    weights[condition] = total_weight / total_weight_all

# Prepare data for radar chart
labels = list(safest_conditions.keys())
values = [weights[label] for label in labels]
angles = [i / float(len(labels)) * 2 * pi for i in range(len(labels))]
values += values[:1]
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='green', alpha=0.25)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)

# Adding labels and title
ax.set_title('Safety Contribution of Driving Conditions')

# Add numerical data labels
for angle, label, value in zip(angles, labels, values):
    ax.text(angle, value, f'{value:.2%}', ha='center', va='center')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# Load the dataset
df_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(df_path)

# Select the relevant columns for the spider chart
selected_columns = ['ΜΗΝΑΣ', 'ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ', 'ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ', 'ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ', 'ΠΕΡΙΦΕΡΕΙΕΣ', 'ΕΙΔΟΣ ΟΔΟΥ', 'ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ']
df_spider = df[selected_columns]

# Function to plot spider chart
def plot_spider_chart(row, ax):
    categories = df_spider.columns
    values = row[selected_columns].values

    num_vars = len(categories)
    angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
    angles += angles[:1]

    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    ax.set_rlabel_position(0)
    ax.set_yticklabels([])
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    ax.plot(angles, values, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color='skyblue', alpha=0.4)

# Create subplots for each row in the dataset
fig, axes = plt.subplots(nrows=len(df), ncols=1, subplot_kw=dict(projection='polar'), figsize=(10, 5 * len(df)))

# Plot spider charts
for i, ax in enumerate(axes):
    plot_spider_chart(df_spider.iloc[i], ax)

# Add numerical values to the plot
for i, ax in enumerate(axes):
    categories = df_spider.columns
    values = df_spider.iloc[i][selected_columns].values
    for j, (angle, value) in enumerate(zip(angles, values)):
        ax.text(angle, ax.get_rmax() + 1, f"{categories[j]}: {value}", ha='center', va='center')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 11
#       9 # Select the relevant columns for the spider chart
#      10 selected_columns = ['ΜΗΝΑΣ', 'ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ', 'ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ', 'ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ', 'ΠΕΡΙΦΕΡΕΙΕΣ', 'ΕΙΔΟΣ ΟΔΟΥ', 'ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ']
# ---> 11 df_spider = df[selected_columns]
#      13 # Function to plot spider chart
#      14 def plot_spider_chart(row, ax):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6173, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     if use_interval_msg:
#    6172         key = list(key)
# -> 6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['ΜΗΝΑΣ', 'ΗΜΕΡΑ ΕΒΔΟΜΑΔΑΣ', 'ΩΡΑ ΑΤΥΧΗΜΑΤΟΣ', 'ΕΙΔΟΣ ΠΕΡΙΟΧΗΣ',\n       'ΠΕΡΙΦΕΡΕΙΕΣ', 'ΕΙΔΟΣ ΟΔΟΥ', 'ΜΕΣΟ ΜΕΤΑΦΟΡΑΣ'],\n      dtype='object')] are in the [columns]"

# %%
# Import necessary libraries
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots


# Initialize the Dash app
app = dash.Dash(__name__)

# Define the app layout
app.layout = html.Div([
    html.Label('Select Category:'),
    dcc.Dropdown(
        id='category-dropdown',
        options=[{'label': category, 'value': category} for category in ['All'] + list(df['Category'].unique())],
        value='All'
    ),
    html.Label('Select Subcategory:'),
    dcc.Dropdown(id='subcategory-dropdown', options=[{'label': 'All', 'value': 'All'}], multi=True),
    html.Label('Select Year:'),
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': year, 'value': year} for year in ['All'] + list(df.columns[2:])],
        value=['All'],
        multi=True
    ),
    dcc.Graph(id='result-plot'),
    dcc.Graph(id='comparison-plot')
])

# Define callback to update subcategories dropdown based on selected category
@app.callback(
    Output('subcategory-dropdown', 'options'),
    [Input('category-dropdown', 'value')]
)
def update_subcategories(selected_category):
    subcategories = ['All'] + list(df[df['Category'] == selected_category]['Subcategory'].unique())
    return [{'label': subcategory, 'value': subcategory} for subcategory in subcategories]

# Define callback to update the plot based on selected options
@app.callback(
    [Output('result-plot', 'figure'),
     Output('comparison-plot', 'figure')],
    [Input('category-dropdown', 'value'),
     Input('subcategory-dropdown', 'value'),
     Input('year-dropdown', 'value')]
)
def update_plot(selected_category, selected_subcategories, selected_years):
    filtered_df = df.copy()

    # Initialize result_fig and comparison_fig
    result_fig = go.Figure()
    
    # Check if there are selected years
    if selected_years and 'All' not in selected_years:
        comparison_fig = make_subplots(rows=len(selected_years), cols=1, shared_xaxes=True,
                                       subplot_titles=selected_years)

        if selected_category != 'All':
            filtered_df = filtered_df[filtered_df['Category'] == selected_category]

        if selected_subcategories and 'All' not in selected_subcategories:
            filtered_df = filtered_df[filtered_df['Subcategory'].isin(selected_subcategories)]

        # Filter the DataFrame based on selected years
        selected_years = [col for col in selected_years if col in df.columns]
        filtered_df = filtered_df[['Category', 'Subcategory'] + selected_years]

        if not filtered_df.empty:
            # Calculate percentage columns for each selected year
            for year in selected_years:
                filtered_df[f'{year}_percentage'] = (filtered_df[year] / filtered_df[year].sum()) * 100
                filtered_df[f'{year}_count'] = filtered_df[year]

            # Bar plot for selected category, subcategories, and years
            result_fig = px.bar(filtered_df.melt(id_vars=['Category', 'Subcategory'], var_name='Year'),
                                x='Subcategory', y='value', color='Subcategory',
                                facet_col='Year', facet_col_wrap=1,
                                labels={'Subcategory': 'Subcategory', 'value': 'Percentage'},
                                title='Accident Percentage by Subcategory')

            # Comparative plot using scatter plot for each selected year
            for i, year in enumerate(selected_years):
                scatter_fig = px.scatter(filtered_df, x='Subcategory', y=f'{year}_percentage',
                                         color='Subcategory',
                                         labels={'Subcategory': 'Subcategory', f'{year}_percentage': 'Percentage'},
                                         title=f'Comparative Accident Percentage by Subcategory for {year}',
                                         hover_data=[f'{year}_percentage', f'{year}_count'])

                # Add each scatter plot as a trace to the subplot
                for trace in scatter_fig['data']:
                    comparison_fig.add_trace(trace, row=i + 1, col=1)

                # Print insights about the comparison plot
                print(f"Insights for {year} comparison plot:")
                print(filtered_df[[year, f'{year}_percentage', f'{year}_count']])

            comparison_fig.update_layout(height=500 * len(selected_years), showlegend=False)

        else:
            # If filtered_df is empty, append an empty bar plot to the list
            comparison_fig = go.Figure()
            comparison_fig.add_trace(go.Scatter(x=[], y=[], mode='markers', marker=dict(color='white')),
                                     row=1, col=1)
            comparison_fig.update_layout(height=500, showlegend=False)

    else:
        # If no years are selected, create an empty figure
        comparison_fig = go.Figure()

    return result_fig, comparison_fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 1  1442            100.0        1442
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 1  1442            100.0        1442
# Insights for 2008 comparison plot:
#    2008  2008_percentage  2008_count
# 1  1411            100.0        1411
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 1  1442            100.0        1442
# Insights for 2008 comparison plot:
#    2008  2008_percentage  2008_count
# 1  1411            100.0        1411
# Insights for 2010 comparison plot:
#    2010  2010_percentage  2010_count
# 1  1142            100.0        1142
# Insights for 2007 comparison plot:
#     2007  2007_percentage  2007_count
# 1   1442         9.303826        1442
# 2  14057        90.696174       14057
# Insights for 2008 comparison plot:
#     2008  2008_percentage  2008_count
# 1   1411         9.354903        1411
# 2  13672        90.645097       13672
# Insights for 2010 comparison plot:
#     2010  2010_percentage  2010_count
# 1   1142         7.597126        1142
# 2  13890        92.402874       13890

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

# Define the app layout
app.layout = html.Div([
    html.Label('Select Category:'),
    dcc.Dropdown(
        id='category-dropdown',
        options=[{'label': category, 'value': category} for category in ['All'] + list(df['Category'].unique())],
        value='All'
    ),
    html.Label('Select Subcategory:'),
    dcc.Dropdown(id='subcategory-dropdown', options=[{'label': 'All', 'value': 'All'}], multi=True),
    html.Label('Select Year:'),
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': year, 'value': year} for year in ['All'] + list(df.columns[2:])],
        value=['All'],
        multi=True
    ),
    dcc.Graph(id='result-plot'),
    dcc.Graph(id='comparison-plot')
])

# Define callback to update subcategories dropdown based on selected category
@app.callback(
    Output('subcategory-dropdown', 'options'),
    [Input('category-dropdown', 'value')]
)
def update_subcategories(selected_category):
    subcategories = ['All'] + list(df[df['Category'] == selected_category]['Subcategory'].unique())
    return [{'label': subcategory, 'value': subcategory} for subcategory in subcategories]

# Define callback to update the plot based on selected options
@app.callback(
    [Output('result-plot', 'figure'),
     Output('comparison-plot', 'figure')],
    [Input('category-dropdown', 'value'),
     Input('subcategory-dropdown', 'value'),
     Input('year-dropdown', 'value')]
)
def update_plot(selected_category, selected_subcategories, selected_years):
    filtered_df = df.copy()

    # Initialize result_fig and comparison_fig
    result_fig = go.Figure()
    comparison_fig = make_subplots(rows=len(selected_years), cols=1, shared_xaxes=True,
                                   subplot_titles=selected_years)

    if selected_category != 'All':
        filtered_df = filtered_df[filtered_df['Category'] == selected_category]

    if selected_subcategories and 'All' not in selected_subcategories:
        filtered_df = filtered_df[filtered_df['Subcategory'].isin(selected_subcategories)]

    if selected_years and 'All' not in selected_years:
        # Filter the DataFrame based on selected years
        selected_years = [col for col in selected_years if col in df.columns]
        filtered_df = filtered_df[['Category', 'Subcategory'] + selected_years]

        if not filtered_df.empty:
            # Calculate percentage columns for each selected year
            for year in selected_years:
                filtered_df[f'{year}_percentage'] = (filtered_df[year] / filtered_df[year].sum()) * 100
                filtered_df[f'{year}_count'] = filtered_df[year]

            # Bar plot for selected category, subcategories, and years
            result_fig = px.bar(filtered_df.melt(id_vars=['Category', 'Subcategory'], var_name='Year'),
                                x='Subcategory', y='value', color='Subcategory',
                                facet_col='Year', facet_col_wrap=1,
                                labels={'Subcategory': 'Subcategory', 'value': 'Percentage'},
                                title='Accident Percentage by Subcategory')

            # Comparative plot using scatter plot for each selected year
            for i, year in enumerate(selected_years):
                scatter_fig = px.scatter(filtered_df, x='Subcategory', y=f'{year}_percentage',
                                         color='Subcategory',
                                         labels={'Subcategory': 'Subcategory', f'{year}_percentage': 'Percentage'},
                                         title=f'Comparative Accident Percentage by Subcategory for {year}',
                                         hover_data=[f'{year}_percentage', f'{year}_count'])

                # Add each scatter plot as a trace to the subplot
                for trace in scatter_fig['data']:
                    comparison_fig.add_trace(trace, row=i + 1, col=1)

                # Print insights about the comparison plot
                print(f"Insights for {year} comparison plot:")
                print(filtered_df[[year, f'{year}_percentage', f'{year}_count']])

            comparison_fig.update_layout(height=500 * len(selected_years), showlegend=False)

        else:
            # If filtered_df is empty, append an empty bar plot to the list
            comparison_fig.add_trace(go.Scatter(x=[], y=[], mode='markers', marker=dict(color='white')),
                                     row=1, col=1)
            comparison_fig.update_layout(height=500, showlegend=False)

    else:
        # If no years are selected, append an empty bar plot to the list
        comparison_fig.add_trace(go.Scatter(x=[], y=[], mode='markers', marker=dict(color='white')),
                                 row=1, col=1)
        comparison_fig.update_layout(height=500, showlegend=False)

    return result_fig, comparison_fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\subplots.py:305, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#       7 def make_subplots(
#       8     rows=1,
#       9     cols=1,
#    (...)
#      26     **kwargs,
#      27 ) -> go.Figure:
#      28     """
#      29     Return an instance of plotly.graph_objs.Figure with predefined subplots
#      30     configured in 'layout'.
#    (...)
#     302     Figure(...)
#     303     """
# --> 305     return _sub.make_subplots(
#         _sub = <module 'plotly._subplots' from 'C:\\Users\\EFKA-PC\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\plotly\\_subplots.py'>
#         rows = 0
#         cols = 1
#         shared_xaxes = True
#         shared_yaxes = False
#         start_cell = 'top-left'
#         print_grid = False
#         horizontal_spacing = None
#         vertical_spacing = None
#         subplot_titles = []
#         column_widths = None
#         row_heights = None
#         specs = None
#         insets = None
#         column_titles = None
#         row_titles = None
#         x_title = None
#         y_title = None
#         figure = None
#         kwargs = {}
#     306         rows,
#     307         cols,
#     308         shared_xaxes,
#     309         shared_yaxes,
#     310         start_cell,
#     311         print_grid,
#     312         horizontal_spacing,
#     313         vertical_spacing,
#     314         subplot_titles,
#     315         column_widths,
#     316         row_heights,
#     317         specs,
#     318         insets,
#     319         column_titles,
#     320         row_titles,
#     321         x_title,
#     322         y_title,
#     323         figure,
#     324         **kwargs,
#     325     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\_subplots.py:362, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#     358     # Validate coerce inputs
#     359     # ----------------------
#     360     #  ### rows ###
#     361     if not isinstance(rows, int) or rows <= 0:
# --> 362         raise ValueError(
#         rows = 0
#         type(rows) = <class 'int'>
#         repr(rows) = '0'
#     363             """
#     364 The 'rows' argument to make_suplots must be an int greater than 0.
#     365     Received value of type {typ}: {val}""".format(
#     366                 typ=type(rows), val=repr(rows)
#     367             )
#     368         )
#     370     #  ### cols ###
#     371     if not isinstance(cols, int) or cols <= 0:
#
# ValueError:
# The 'rows' argument to make_suplots must be an int greater than 0.
#     Received value of type <class 'int'>: 0
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\subplots.py:305, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#       7 def make_subplots(
#       8     rows=1,
#       9     cols=1,
#    (...)
#      26     **kwargs,
#      27 ) -> go.Figure:
#      28     """
#      29     Return an instance of plotly.graph_objs.Figure with predefined subplots
#      30     configured in 'layout'.
#    (...)
#     302     Figure(...)
#     303     """
# --> 305     return _sub.make_subplots(
#         _sub = <module 'plotly._subplots' from 'C:\\Users\\EFKA-PC\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\plotly\\_subplots.py'>
#         rows = 0
#         cols = 1
#         shared_xaxes = True
#         shared_yaxes = False
#         start_cell = 'top-left'
#         print_grid = False
#         horizontal_spacing = None
#         vertical_spacing = None
#         subplot_titles = []
#         column_widths = None
#         row_heights = None
#         specs = None
#         insets = None
#         column_titles = None
#         row_titles = None
#         x_title = None
#         y_title = None
#         figure = None
#         kwargs = {}
#     306         rows,
#     307         cols,
#     308         shared_xaxes,
#     309         shared_yaxes,
#     310         start_cell,
#     311         print_grid,
#     312         horizontal_spacing,
#     313         vertical_spacing,
#     314         subplot_titles,
#     315         column_widths,
#     316         row_heights,
#     317         specs,
#     318         insets,
#     319         column_titles,
#     320         row_titles,
#     321         x_title,
#     322         y_title,
#     323         figure,
#     324         **kwargs,
#     325     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\_subplots.py:362, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#     358     # Validate coerce inputs
#     359     # ----------------------
#     360     #  ### rows ###
#     361     if not isinstance(rows, int) or rows <= 0:
# --> 362         raise ValueError(
#         rows = 0
#         type(rows) = <class 'int'>
#         repr(rows) = '0'
#     363             """
#     364 The 'rows' argument to make_suplots must be an int greater than 0.
#     365     Received value of type {typ}: {val}""".format(
#     366                 typ=type(rows), val=repr(rows)
#     367             )
#     368         )
#     370     #  ### cols ###
#     371     if not isinstance(cols, int) or cols <= 0:
#
# ValueError:
# The 'rows' argument to make_suplots must be an int greater than 0.
#     Received value of type <class 'int'>: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\subplots.py:305, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#       7 def make_subplots(
#       8     rows=1,
#       9     cols=1,
#    (...)
#      26     **kwargs,
#      27 ) -> go.Figure:
#      28     """
#      29     Return an instance of plotly.graph_objs.Figure with predefined subplots
#      30     configured in 'layout'.
#    (...)
#     302     Figure(...)
#     303     """
# --> 305     return _sub.make_subplots(
#         _sub = <module 'plotly._subplots' from 'C:\\Users\\EFKA-PC\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\plotly\\_subplots.py'>
#         rows = 0
#         cols = 1
#         shared_xaxes = True
#         shared_yaxes = False
#         start_cell = 'top-left'
#         print_grid = False
#         horizontal_spacing = None
#         vertical_spacing = None
#         subplot_titles = []
#         column_widths = None
#         row_heights = None
#         specs = None
#         insets = None
#         column_titles = None
#         row_titles = None
#         x_title = None
#         y_title = None
#         figure = None
#         kwargs = {}
#     306         rows,
#     307         cols,
#     308         shared_xaxes,
#     309         shared_yaxes,
#     310         start_cell,
#     311         print_grid,
#     312         horizontal_spacing,
#     313         vertical_spacing,
#     314         subplot_titles,
#     315         column_widths,
#     316         row_heights,
#     317         specs,
#     318         insets,
#     319         column_titles,
#     320         row_titles,
#     321         x_title,
#     322         y_title,
#     323         figure,
#     324         **kwargs,
#     325     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\_subplots.py:362, in make_subplots(
#     rows=0,
#     cols=1,
#     shared_xaxes=True,
#     shared_yaxes=False,
#     start_cell='top-left',
#     print_grid=False,
#     horizontal_spacing=None,
#     vertical_spacing=None,
#     subplot_titles=[],
#     column_widths=None,
#     row_heights=None,
#     specs=None,
#     insets=None,
#     column_titles=None,
#     row_titles=None,
#     x_title=None,
#     y_title=None,
#     figure=None,
#     **kwargs={}
# )
#     358     # Validate coerce inputs
#     359     # ----------------------
#     360     #  ### rows ###
#     361     if not isinstance(rows, int) or rows <= 0:
# --> 362         raise ValueError(
#         rows = 0
#         type(rows) = <class 'int'>
#         repr(rows) = '0'
#     363             """
#     364 The 'rows' argument to make_suplots must be an int greater than 0.
#     365     Received value of type {typ}: {val}""".format(
#     366                 typ=type(rows), val=repr(rows)
#     367             )
#     368         )
#     370     #  ### cols ###
#     371     if not isinstance(cols, int) or cols <= 0:
#
# ValueError:
# The 'rows' argument to make_suplots must be an int greater than 0.
#     Received value of type <class 'int'>: 0
#
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 1  1442            100.0        1442
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 1  1442            100.0        1442
# Insights for 2008 comparison plot:
#    2008  2008_percentage  2008_count
# 1  1411            100.0        1411

# %%
from IPython.display import clear_output
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# Assuming df is your DataFrame containing the data

# Dropdown widget for selecting Category
categories = ['All'] + list(df['Category'].unique())
category_dropdown = widgets.Dropdown(
    options=categories,
    description='Select Category:'
)

# Output widget to display selected categories and subcategories
output = widgets.Output()

# Dropdown widget for selecting Subcategory
subcategories = ['All']
subcategory_dropdown = widgets.Dropdown(
    options=subcategories,
    description='Select Subcategory:'
)

def update_subcategories_options(change):
    selected_category = category_dropdown.value
    subcategories = ['All'] + list(df[df['Category'] == selected_category]['Subcategory'].unique())
    subcategory_dropdown.options = subcategories

def reset_options(change):
    with output:
        clear_output(wait=True)
        category_dropdown.value = 'All'
        subcategory_dropdown.options = ['All']
        subcategory_dropdown.value = 'All'
        year_dropdown.value = 'All'
        print("All options reset.")

def handle_dropdown_change(change):
    with output:
        clear_output(wait=True)  # Use clear_output(wait=True) to clear the output without flickering
        selected_category = category_dropdown.value
        selected_subcategory = subcategory_dropdown.value
        selected_year = year_dropdown.value
        
        filtered_df = df.copy()

        if selected_category != 'All':
            filtered_df = filtered_df[filtered_df['Category'] == selected_category]

        if selected_subcategory != 'All' and selected_subcategory not in subcategory_dropdown.options:
            print(f"Invalid subcategory selected: {selected_subcategory}")
            return

        if selected_subcategory != 'All':
            filtered_df = filtered_df[filtered_df['Subcategory'] == selected_subcategory]

        if selected_year != 'All':
            filtered_df = filtered_df[['Category', 'Subcategory', selected_year]]
            if not filtered_df.empty:
                lowest_row = filtered_df.loc[filtered_df[selected_year].idxmin()]
                print(f"Lowest Value for {selected_year}:")
                print(lowest_row)
            else:
                print("No data available for the selected filters.")

        display(filtered_df)

category_dropdown.observe(update_subcategories_options, names='value')
subcategory_dropdown.observe(handle_dropdown_change, names='value')

# Dropdown widget for selecting Year
years = ['All'] + list(df.columns[2:])
year_dropdown = widgets.Dropdown(
    options=years,
    description='Select Year:'
)
year_dropdown.observe(handle_dropdown_change, names='value')

# Button to reset options
reset_button = widgets.Button(description="Reset Options")
reset_button.on_click(reset_options)

widgets.VBox([category_dropdown, subcategory_dropdown, year_dropdown, reset_button, output])
# Out:
# VBox(children=(Dropdown(description='Select Category:', options=('All', 'Σύνολο ατυχημάτων', 'ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ'…

# %%
from IPython.display import clear_output
import pandas as pd
import ipywidgets as widgets
import plotly.express as px  # Assuming you want to use Plotly for interactive visualizations
from IPython.display import display

# Assuming df is your DataFrame containing the data

# Dropdown widget for selecting Category
categories = ['All'] + list(df['Category'].unique())
category_dropdown = widgets.Dropdown(
    options=categories,
    description='Select Category:'
)

# Output widget to display selected categories and subcategories
output = widgets.Output()

# Dropdown widget for selecting Subcategory
subcategories = ['All']
subcategory_dropdown = widgets.Dropdown(
    options=subcategories,
    description='Select Subcategory:'
)

def update_subcategories_options(change):
    selected_category = category_dropdown.value
    subcategories = ['All'] + list(df[df['Category'] == selected_category]['Subcategory'].unique())
    subcategory_dropdown.options = subcategories

def reset_options(change):
    with output:
        clear_output(wait=True)
        category_dropdown.value = 'All'
        subcategory_dropdown.options = ['All']
        subcategory_dropdown.value = 'All'
        year_dropdown.value = 'All'
        print("All options reset.")

def handle_dropdown_change(change):
    with output:
        clear_output(wait=True)  # Use clear_output(wait=True) to clear the output without flickering
        selected_category = category_dropdown.value
        selected_subcategory = subcategory_dropdown.value
        selected_year = year_dropdown.value
        
        filtered_df = df.copy()

        if selected_category != 'All':
            filtered_df = filtered_df[filtered_df['Category'] == selected_category]

        if selected_subcategory != 'All' and selected_subcategory not in subcategory_dropdown.options:
            print(f"Invalid subcategory selected: {selected_subcategory}")
            return

        if selected_subcategory != 'All':
            filtered_df = filtered_df[filtered_df['Subcategory'] == selected_subcategory]

        if selected_year != 'All':
            filtered_df = filtered_df[['Category', 'Subcategory', selected_year]]
            if not filtered_df.empty:
                lowest_row = filtered_df.loc[filtered_df[selected_year].idxmin()]
                print(f"Lowest Value for {selected_year}:")
                print(lowest_row)
                # Create an interactive plot using Plotly
                fig = px.bar(filtered_df, x='Category', y=selected_year, color='Subcategory',
                             labels={'Category': 'Category', selected_year: 'Accident Count'},
                             title=f'Accident Count by Category and Subcategory for {selected_year}')
                fig.show()
            else:
                print("No data available for the selected filters.")

        display(filtered_df)

category_dropdown.observe(update_subcategories_options, names='value')
subcategory_dropdown.observe(handle_dropdown_change, names='value')

# Dropdown widget for selecting Year
years = ['All'] + list(df.columns[2:])
year_dropdown = widgets.Dropdown(
    options=years,
    description='Select Year:'
)
year_dropdown.observe(handle_dropdown_change, names='value')

# Button to reset options
reset_button = widgets.Button(description="Reset Options")
reset_button.on_click(reset_options)

widgets.VBox([category_dropdown, subcategory_dropdown, year_dropdown, reset_button, output])
# Out:
# VBox(children=(Dropdown(description='Select Category:', options=('All', 'Σύνολο ατυχημάτων', 'ΦΥΣΗ ΑΤΥΧΗΜΑΤΟΣ'…

# %% [markdown]
# ## JANUARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
csv_file_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(csv_file_path)

# Data Cleaning and Preprocessing (if needed)

# Extract the month names from rows 25 to 36
months = df.iloc[25:37, 1].tolist()  # Assuming row 25 column 1 contains the month names

# Extract the corresponding values for the years 2007-2021 for January
january_row_index = 25  # Assuming January is always in row 25
january_accidents = df.iloc[january_row_index, 2:]

# Create the bar plot for January's accident count with integers labels
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=january_accidents.index, y=january_accidents.values)

# Add integer labels above the bars
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.xlabel("Year")
plt.ylabel("Accident Count")
plt.title("January Accident Count for All Years (2007-2021)")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
csv_file_path = 'C:/Users/EFKA-PC/Desktop/github1/odika/data.csv'
df = pd.read_csv(csv_file_path)

# Data Cleaning and Preprocessing (if needed)

# Extract the month names from rows 25 to 36
months = df.iloc[25:37, 1].tolist()  # Assuming row 25 column 1 contains the month names

# Extract the corresponding values for the years 2007-2021 for February
february_row_index = 26  # Assuming February is in row 26
february_accidents = df.iloc[february_row_index, 2:]

# Create the bar plot for February's accident count with integers labels
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=february_accidents.index, y=february_accidents.values)

# Add integer labels above the bars
for p in ax.patches:
    ax.annotate(str(int(p.get_height())), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.xlabel("Year")
plt.ylabel("Accident Count")
plt.title("February Accident Count for All Years (2007-2021)")
plt.xticks(rotation=45)
plt.show()
# Out:
# Insights for 2007 comparison plot:
#    2007  2007_percentage  2007_count
# 3  7918            100.0        7918
# Insights for 2008 comparison plot:
#    2008  2008_percentage  2008_count
# 3  7562            100.0        7562
